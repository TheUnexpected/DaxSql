# %%
import snowflake.connector
from snowflake.sqlalchemy import URL
from sqlalchemy import create_engine
import pyodbc
import pandas as pd
from datetime import datetime, timedelta
import numpy as np
from statsmodels.tsa.statespace.sarimax import SARIMAX
#from statsmodels.tsa.holtwinters import ExponentialSmoothing
#import plotly.express as px
from pmdarima import auto_arima
#from prophet import Prophet
from sklearn.metrics import mean_squared_error, mean_absolute_error
#from arch import arch_model

# %%
'''
con_str = (
    "Driver={SQL Server};"
    "Server=lnmxvmsqlqa02;"
    "Database=HDI_DWH;"
    "Trusted_Connection=yes"
)
'''
url = URL(
    account='xxxxx',
    user='xxxxx',
    password='xxxxx',
    database='xxxx',
    schema='PUBLIC',
    warehouse='DATALAKE_WH',
    role='VENTAS_ROLE'    
)

engine = create_engine(url)
conn = engine.connect()

query = """
SELECT 
        date_from_parts(tecnica.periodo/100, tecnica.periodo%100,01) as fecha,
        oficina.direccion,
        oficina.subdireccion,
        oficina.oficinacomercial "OFICINA",
        tecnica.primanetapropiasincoaseguro as "PrimaEmitida"
        
FROM TB_BI_AUTRFACTEMISIONDOC emision
    INNER JOIN TB_BI_AUTRBASETECNICA  tecnica
        ON emision.numcompletocotizacion = tecnica.numcompletocotizacion
        AND emision.numdocumento = tecnica.numdocumento
    LEFT JOIN TB_BI_CATAGENTE agente
        ON emision.nipperfilagente = agente.nipperfilagente
    LEFT JOIN TB_DL_CATOFICINACOMERCIAL oficina
        ON agente.idoficinaagente = oficina.idoficina
WHERE 
    tecnica.periodo between 202001 and 202505
    and emision.idtipopoliza = 4013
    and direccion in ('Bajio - Occidente','Norte','Mexico - Sur')
    and emision.idtipovehiculo in (4579, 3829)
GROUP BY all;
"""
try:     
    df = pd.read_sql(query,conn)
    print(df.head(10))
    conn.close()
except pyodbc.Error as ex:
    print("Error en SQL Server:", ex)
# Out:
#         fecha          direccion        subdireccion  \
# 0  2022-11-01       Mexico - Sur  Mexico Promotorias
# 1  2022-11-01              Norte             Noreste
# 2  2022-11-01       Mexico - Sur                 Sur
# 3  2022-11-01  Bajio - Occidente           Occidente
# 4  2022-11-01       Mexico - Sur  Mexico Promotorias
# 5  2022-01-01  Bajio - Occidente               Bajio
# 6  2022-11-01  Bajio - Occidente               Bajio
# 7  2022-11-01  Bajio - Occidente               Bajio
# 8  2022-11-01              Norte            Noroeste
# 9  2022-11-01       Mexico - Sur  Mexico Promotorias
#
#                           oficina  PrimaEmitida
# 0     Promotorías México Satélite        0.0000
# 1                         Torreón    -6467.4547
# 2                          Cancún        0.0000
# 3           Guadalajara Despachos        0.0000
# 4  Promotorías México Insurgentes     7620.6303
# 5                         Pachuca        0.0000
# 6                         Pachuca        0.0000
# 7                        Irapuato        0.0000
# 8                   Ciudad Juárez        0.0000
# 9      Promotorías México Polanco        0.0000

# %%
#Ajustar datos
df['fecha'] = pd.to_datetime(df['fecha'])
df = df.groupby(['subdireccion','fecha'])['PrimaEmitida'].sum().reset_index()
#df = df.pivot(index='fecha', columns='subdireccion', values='PrimaEmitida').fillna(0)

# %%
# Validar formato de fechas
invalid_dates = df[~df['fecha'].apply(lambda x: isinstance(x, pd.Timestamp))]
if not invalid_dates.empty:
    print("Fechas inválidas:\n", invalid_dates)

# %%
#scale_factor = 1e5
#df_scale = df / scale_factor
#Forecast
forecasts= []
for subdireccion in df['subdireccion'].unique():
    df_subdir = df[df['subdireccion'] == subdireccion].set_index('fecha').asfreq('MS')['PrimaEmitida']

    if not isinstance(df_subdir.index, pd.DatetimeIndex):
        df_subdir.index = pd.to_datetime(df_subdir.index)

    #modelo SARIMA con autoarima
    model = auto_arima(df_subdir, seasonal=True, m=12, trace=True, error_action='ignore', suppress_warnings=True)
    print(f"SubDireccion: {subdireccion}, SARIMA: {model.order}, Seasonal: {model.seasonal_order}")

    n_periods= 6
    forecast, conf_int = model.predict(n_periods=n_periods, return_conf_int=True)

    #DF
    future_fechas = pd.date_range(start='2025-05-01', periods=n_periods, freq='MS')
    forecast_df = pd.DataFrame({
        'Fechas':future_fechas,
        'Forecast': forecast,
        'LOWER_CI': conf_int[:,0],
        'UPPER_CI': conf_int[:,1],
        'P_Moncada': conf_int[:,1]*.95,
        'SubDir': subdireccion
    })
    forecasts.append(forecast_df)
    
forecast_fin = pd.concat(forecasts)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=0.24 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=2127.116, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=2128.223, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=2128.097, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=2125.138, Time=0.01 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=2128.518, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=2128.596, Time=0.02 sec
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=2130.346, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=2126.870, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=2126.692, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=2123.688, Time=0.03 sec
#  ARIMA(1,1,1)(1,0,0)[12] intercept   : AIC=2125.392, Time=0.08 sec
#  ARIMA(1,1,1)(0,0,1)[12] intercept   : AIC=2125.149, Time=0.07 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=2124.912, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=2122.813, Time=0.04 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=2124.412, Time=0.09 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=2124.548, Time=0.07 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=2126.570, Time=0.02 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=2125.313, Time=0.03 sec
#  ARIMA(1,1,3)(0,0,0)[12] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(0,1,3)(0,0,0)[12] intercept   : AIC=2122.142, Time=0.03 sec
#  ARIMA(0,1,3)(1,0,0)[12] intercept   : AIC=2123.458, Time=0.06 sec
#  ARIMA(0,1,3)(0,0,1)[12] intercept   : AIC=2123.693, Time=0.06 sec
#  ARIMA(0,1,3)(1,0,1)[12] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(0,1,4)(0,0,0)[12] intercept   : AIC=2137.775, Time=0.02 sec
#  ARIMA(1,1,4)(0,0,0)[12] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(0,1,3)(0,0,0)[12]             : AIC=2121.460, Time=0.02 sec
#  ARIMA(0,1,3)(1,0,0)[12]             : AIC=2122.758, Time=0.05 sec
#  ARIMA(0,1,3)(0,0,1)[12]             : AIC=2122.861, Time=0.04 sec
#  ARIMA(0,1,3)(1,0,1)[12]             : AIC=2124.549, Time=0.11 sec
#  ARIMA(0,1,2)(0,0,0)[12]             : AIC=2124.618, Time=0.01 sec
#  ARIMA(1,1,3)(0,0,0)[12]             : AIC=2122.402, Time=0.03 sec
#  ARIMA(0,1,4)(0,0,0)[12]             : AIC=2125.078, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[12]             : AIC=2122.154, Time=0.03 sec
#  ARIMA(1,1,4)(0,0,0)[12]             : AIC=2126.979, Time=0.06 sec
#
# Best model:  ARIMA(0,1,3)(0,0,0)[12]
# Total fit time: 2.275 seconds
# SubDireccion: Bajio, SARIMA: (0, 1, 3), Seasonal: (0, 0, 0, 12)
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=0.33 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=2084.204, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=2082.604, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=2079.154, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=2082.216, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=2077.298, Time=0.02 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=2079.158, Time=0.05 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=2081.151, Time=0.07 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=2072.119, Time=0.03 sec
#  ARIMA(1,1,1)(1,0,0)[12] intercept   : AIC=2073.596, Time=0.08 sec
#  ARIMA(1,1,1)(0,0,1)[12] intercept   : AIC=2074.076, Time=0.06 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=2080.727, Time=0.01 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=2081.412, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=2071.180, Time=0.03 sec
#  ARIMA(0,1,2)(1,0,0)[12] intercept   : AIC=2073.171, Time=0.06 sec
#  ARIMA(0,1,2)(0,0,1)[12] intercept   : AIC=2073.179, Time=0.06 sec
#  ARIMA(0,1,2)(1,0,1)[12] intercept   : AIC=2075.142, Time=0.12 sec
#  ARIMA(0,1,3)(0,0,0)[12] intercept   : AIC=2074.534, Time=0.02 sec
#  ARIMA(1,1,3)(0,0,0)[12] intercept   : AIC=2076.795, Time=0.04 sec
#  ARIMA(0,1,2)(0,0,0)[12]             : AIC=2072.096, Time=0.02 sec
#
# Best model:  ARIMA(0,1,2)(0,0,0)[12] intercept
# Total fit time: 1.280 seconds
# SubDireccion: Mexico Despachos, SARIMA: (0, 1, 2), Seasonal: (0, 0, 0, 12)
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=2062.043, Time=0.19 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=2090.972, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=2067.537, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=2072.811, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=2307.591, Time=0.00 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=2069.941, Time=0.07 sec
#  ARIMA(2,0,2)(1,0,0)[12] intercept   : AIC=2072.322, Time=0.12 sec
#  ARIMA(2,0,2)(2,0,1)[12] intercept   : AIC=2062.259, Time=0.47 sec
#  ARIMA(2,0,2)(1,0,2)[12] intercept   : AIC=2062.476, Time=0.45 sec
#  ARIMA(2,0,2)(0,0,0)[12] intercept   : AIC=2074.183, Time=0.04 sec
#  ARIMA(2,0,2)(0,0,2)[12] intercept   : AIC=2068.518, Time=0.21 sec
#  ARIMA(2,0,2)(2,0,0)[12] intercept   : AIC=inf, Time=nan sec
#  ARIMA(2,0,2)(2,0,2)[12] intercept   : AIC=2064.260, Time=0.62 sec
#  ARIMA(1,0,2)(1,0,1)[12] intercept   : AIC=2066.385, Time=0.13 sec
#  ARIMA(2,0,1)(1,0,1)[12] intercept   : AIC=2068.286, Time=0.16 sec
#  ARIMA(3,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=0.35 sec
#  ARIMA(2,0,3)(1,0,1)[12] intercept   : AIC=inf, Time=0.33 sec
#  ARIMA(1,0,1)(1,0,1)[12] intercept   : AIC=2069.482, Time=0.08 sec
#  ARIMA(1,0,3)(1,0,1)[12] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(3,0,1)(1,0,1)[12] intercept   : AIC=2069.242, Time=0.20 sec
#  ARIMA(3,0,3)(1,0,1)[12] intercept   : AIC=inf, Time=0.36 sec
#  ARIMA(2,0,2)(1,0,1)[12]             : AIC=inf, Time=0.25 sec
#
# Best model:  ARIMA(2,0,2)(1,0,1)[12] intercept
# Total fit time: 4.840 seconds
# SubDireccion: Mexico Promotorias, SARIMA: (2, 0, 2), Seasonal: (1, 0, 1, 12)
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=2142.269, Time=0.29 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=2187.262, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=2145.153, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=2154.627, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=2380.074, Time=0.00 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=2143.552, Time=0.09 sec
#  ARIMA(2,0,2)(1,0,0)[12] intercept   : AIC=2140.983, Time=0.14 sec
#  ARIMA(2,0,2)(0,0,0)[12] intercept   : AIC=2159.513, Time=0.04 sec
#  ARIMA(2,0,2)(2,0,0)[12] intercept   : AIC=2142.645, Time=0.32 sec
#  ARIMA(2,0,2)(2,0,1)[12] intercept   : AIC=2143.955, Time=0.49 sec
#  ARIMA(1,0,2)(1,0,0)[12] intercept   : AIC=2141.297, Time=0.06 sec
#  ARIMA(2,0,1)(1,0,0)[12] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(3,0,2)(1,0,0)[12] intercept   : AIC=2142.037, Time=0.18 sec
#  ARIMA(2,0,3)(1,0,0)[12] intercept   : AIC=2142.012, Time=0.14 sec
#  ARIMA(1,0,1)(1,0,0)[12] intercept   : AIC=2143.690, Time=0.05 sec
#  ARIMA(1,0,3)(1,0,0)[12] intercept   : AIC=2141.285, Time=0.08 sec
#  ARIMA(3,0,1)(1,0,0)[12] intercept   : AIC=inf, Time=0.25 sec
#  ARIMA(3,0,3)(1,0,0)[12] intercept   : AIC=2143.739, Time=0.20 sec
#  ARIMA(2,0,2)(1,0,0)[12]             : AIC=2151.775, Time=0.07 sec
#
# Best model:  ARIMA(2,0,2)(1,0,0)[12] intercept
# Total fit time: 2.654 seconds
# SubDireccion: Noreste, SARIMA: (2, 0, 2), Seasonal: (1, 0, 0, 12)
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=2158.619, Time=0.19 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=2195.484, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=2160.008, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=2165.745, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=2419.922, Time=0.00 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=2164.713, Time=0.10 sec
#  ARIMA(2,0,2)(1,0,0)[12] intercept   : AIC=2157.171, Time=0.12 sec
#  ARIMA(2,0,2)(0,0,0)[12] intercept   : AIC=2170.439, Time=0.04 sec
#  ARIMA(2,0,2)(2,0,0)[12] intercept   : AIC=2156.240, Time=0.34 sec
#  ARIMA(2,0,2)(2,0,1)[12] intercept   : AIC=inf, Time=0.63 sec
#  ARIMA(1,0,2)(2,0,0)[12] intercept   : AIC=2156.783, Time=0.25 sec
#  ARIMA(2,0,1)(2,0,0)[12] intercept   : AIC=inf, Time=0.46 sec
#  ARIMA(3,0,2)(2,0,0)[12] intercept   : AIC=2157.590, Time=0.50 sec
#  ARIMA(2,0,3)(2,0,0)[12] intercept   : AIC=2152.589, Time=0.44 sec
#  ARIMA(2,0,3)(1,0,0)[12] intercept   : AIC=2157.208, Time=0.18 sec
#  ARIMA(2,0,3)(2,0,1)[12] intercept   : AIC=inf, Time=0.65 sec
#  ARIMA(2,0,3)(1,0,1)[12] intercept   : AIC=2159.208, Time=0.26 sec
#  ARIMA(1,0,3)(2,0,0)[12] intercept   : AIC=inf, Time=0.31 sec
#  ARIMA(3,0,3)(2,0,0)[12] intercept   : AIC=2156.412, Time=0.69 sec
#  ARIMA(2,0,4)(2,0,0)[12] intercept   : AIC=2154.239, Time=0.52 sec
#  ARIMA(1,0,4)(2,0,0)[12] intercept   : AIC=2153.009, Time=0.31 sec
#  ARIMA(3,0,4)(2,0,0)[12] intercept   : AIC=2155.520, Time=0.75 sec
#  ARIMA(2,0,3)(2,0,0)[12]             : AIC=2166.269, Time=0.34 sec
#
# Best model:  ARIMA(2,0,3)(2,0,0)[12] intercept
# Total fit time: 7.162 seconds
# SubDireccion: Noroeste, SARIMA: (2, 0, 3), Seasonal: (2, 0, 0, 12)
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=2156.955, Time=0.21 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=2159.228, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=2160.852, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=2160.375, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=2157.251, Time=0.00 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=2155.005, Time=0.13 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=2153.694, Time=0.06 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=2154.958, Time=0.13 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=2153.708, Time=0.03 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=2161.269, Time=0.02 sec
#  ARIMA(3,1,2)(0,0,0)[12] intercept   : AIC=2155.540, Time=0.07 sec
#  ARIMA(2,1,3)(0,0,0)[12] intercept   : AIC=2162.131, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=2156.474, Time=0.03 sec
#  ARIMA(1,1,3)(0,0,0)[12] intercept   : AIC=2159.128, Time=0.06 sec
#  ARIMA(3,1,1)(0,0,0)[12] intercept   : AIC=2157.655, Time=0.04 sec
#  ARIMA(3,1,3)(0,0,0)[12] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(2,1,2)(0,0,0)[12]             : AIC=2156.778, Time=0.05 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[12] intercept
# Total fit time: 1.120 seconds
# SubDireccion: Occidente, SARIMA: (2, 1, 2), Seasonal: (0, 0, 0, 12)
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=0.25 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=2174.431, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=2134.487, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=2136.485, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=2365.118, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=2147.175, Time=0.01 sec
#  ARIMA(1,0,0)(2,0,0)[12] intercept   : AIC=2135.998, Time=0.09 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=2133.291, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : AIC=2133.878, Time=0.03 sec
#  ARIMA(1,0,0)(2,0,1)[12] intercept   : AIC=inf, Time=0.37 sec
#  ARIMA(1,0,0)(1,0,2)[12] intercept   : AIC=2133.970, Time=0.08 sec
#  ARIMA(1,0,0)(0,0,2)[12] intercept   : AIC=2133.316, Time=0.05 sec
#  ARIMA(1,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=0.41 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : AIC=2159.496, Time=0.04 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : AIC=2130.656, Time=0.07 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : AIC=2130.446, Time=0.03 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : AIC=2141.631, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,2)[12] intercept   : AIC=2130.648, Time=0.07 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : AIC=2132.795, Time=0.05 sec
#  ARIMA(2,0,0)(1,0,2)[12] intercept   : AIC=2131.566, Time=0.13 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : AIC=2132.349, Time=0.05 sec
#  ARIMA(2,0,1)(0,0,1)[12] intercept   : AIC=2131.646, Time=0.10 sec
#  ARIMA(1,0,1)(0,0,1)[12] intercept   : AIC=2131.455, Time=0.04 sec
#  ARIMA(3,0,1)(0,0,1)[12] intercept   : AIC=2133.617, Time=0.09 sec
#  ARIMA(2,0,0)(0,0,1)[12]             : AIC=2151.353, Time=0.04 sec
#
# Best model:  ARIMA(2,0,0)(0,0,1)[12] intercept
# Total fit time: 2.137 seconds
# SubDireccion: Sur, SARIMA: (2, 0, 0), Seasonal: (0, 0, 1, 12)

# %%
#Guardar datos en excel
forecasts_final = pd.concat(forecasts)
forecasts_final.to_excel('forecast_prima_2025.xlsx', index = False)
#forecast_final.to_sql('forecast_prima_2025', conn, if_exists='replace', index=False)
print("done")
# Out:
# done
